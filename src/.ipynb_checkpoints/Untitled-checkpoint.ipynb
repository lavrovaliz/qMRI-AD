# %%
import os,sys
sys.path.append(os.path.abspath("../The_Dlab_toolbox"))
#from pmtool.analysis_box import analysis_box
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.manifold import MDS
from sklearn.manifold import Isomap, LocallyLinearEmbedding, SpectralEmbedding
from statsmodels.stats import multitest

# %%
from sklearn.linear_model import LogisticRegression

def get_ypred(X, y):
    
    lr = LogisticRegression(fit_intercept=True, solver='lbfgs', max_iter=1000)
    lr.fit(X, y)
    w = np.array(lr.coef_).transpose()
    y_pred = lr.predict_proba(X)[:, 1]
    print(lr.coef_)

    return(y_pred)

def efron_rsquare(y, y_pred):
    n = float(len(y))
    t1 = np.sum(np.power(y - y_pred, 2.0))
    t2 = np.sum(np.power((y - (np.sum(y) / n)), 2.0))
    return 1.0 - (t1 / t2)

# %%
def selectNonUniform(df_in, ftrs, outc):
    
    ftrs_non_constant = df_in[ftrs].std().loc[df_in.round(2).std(axis=0) > 0.0].index.values
    
    non_uniform_features = []
    
    for ftr in ftrs_non_constant:
        
        ftr_freqs = pd.DataFrame(df_in[ftr].round(2).value_counts())
        f1 = int(ftr_freqs.iloc[0])
        f2 = int(ftr_freqs.iloc[1])
        f = len(ftr_freqs)
        p1 = f/len(df_in[ftrs])
        
        p2 = f1/f2
        if p1<=0.1 and p2 >= 95/5:
            print (ftr,  ' excluded')
        else:
            non_uniform_features.append(ftr)
    
    print ('Non uniform features: ', non_uniform_features)
    
    return non_uniform_features


def selectNonIntercorrelated(df_in, ftrs, outc, corr_th):
    
    corr_matrix = df_in.corr(method='spearman').abs()
    mean_absolute_corr = corr_matrix.mean()
    intercorrelated_features_set = []
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
    high_corrs = upper.where(upper > corr_th).dropna(how='all', axis=1).dropna(how='all', axis=0)

    for feature in high_corrs.columns:
        mean_absolute_main = mean_absolute_corr[feature]
        correlated_with_feature = high_corrs[feature].index[pd.notnull(high_corrs[feature])]
        for each_correlated_feature in correlated_with_feature:
            mean_absolute = mean_absolute_corr[each_correlated_feature]
            if mean_absolute_main > mean_absolute:
                if feature not in intercorrelated_features_set:
                    intercorrelated_features_set.append(feature)
            else:
                if each_correlated_feature not in intercorrelated_features_set:
                    intercorrelated_features_set.append(each_correlated_feature)

    non_intercorrelated_features_set = [e for e in ftrs if e not in intercorrelated_features_set] 
    
    print ('Non intercorrelated features: ', non_intercorrelated_features_set)
    
    return non_intercorrelated_features_set


def selectNonCorrelatedToVolume(df_in, ftrs, vol, th):
    
    ftrs_non_vol_corr = []
    
    for ftr in ftrs:
        r, p = stats.spearmanr(df_in[ftr], vol)
        if abs(r)<=th:
            ftrs_non_vol_corr.append(ftr)
            
    return (ftrs_non_vol_corr)


def selectDistinctiveFeatures(df_in, ftrs, outc, th):
    
    ftrs_dst = []
    df_in_0 = df_in.loc[df_in[outc]==0]
    df_in_1 = df_in.loc[df_in[outc]==1]
    
    pvals = []
    
    for ftr in ftrs:
        U1, p = stats.mannwhitneyu(df_in_0[ftr], df_in_1[ftr])
        pvals.append(p)
        
    rej, p_corr = multitest.fdrcorrection(pvals)
    
    for i in range (0, len(ftrs)):
        if p_corr[i]<th:
            ftrs_dst.append(ftrs[i])
            print (ftrs[i], p_corr[i])
            
    return (ftrs_dst)

# %%
def features_selection_pipeline(filename):
    
    df_orig = pd.read_csv(filename)
    columns_filtered = [x for x in df_orig.columns if not (('shape' in x)|('Unnamed' in x))]
    df = df_orig[columns_filtered]
    features = [x for x in df.columns if ('original' in x)]

    X = df[features]
    y = df.outcome

    X_embedded = TSNE(n_components=2, perplexity=5, learning_rate=10).fit_transform(X)

    plt.scatter(X_embedded[y==0, 0], X_embedded[y==0, 1])
    plt.scatter(X_embedded[y==1, 0], X_embedded[y==1, 1])
    plt.show()

    pca = PCA(n_components=2)
    X_r = pca.fit(X).transform(X)

    plt.scatter(X_r[y == 0, 0], X_r[y == 0, 1])
    plt.scatter(X_r[y == 1, 0], X_r[y == 1, 1])
    plt.show()

    lda = LinearDiscriminantAnalysis(n_components=1)
    X_r2 = lda.fit(X, y).transform(X)

    plt.hist(X_r2[y == 0])
    plt.hist(X_r2[y == 1])
    plt.show()

    features_non_uniform = selectNonUniform(df, df.columns[1:-1], y)
    print (len(features_non_uniform))
    
    features_non_volcorrelated = selectNonCorrelatedToVolume(df, features_non_uniform, df_orig.original_shape_VoxelVolume, 0.85)
    print (len(features_non_volcorrelated))

    features_non_intercorrelated = selectNonIntercorrelated(df, features_non_volcorrelated, y, 0.85)
    print (len(features_non_intercorrelated))

    features_distinctive = selectDistinctiveFeatures(df, features_non_intercorrelated, 'outcome', 0.05)
    print (len(features_distinctive))
    
    print ((features_distinctive))

# %%
features_selection_pipeline('Z:/Lisa/CRC_AD/derivatives/hmri/MTsat_R.csv')
# Out:
# original_gldm_SmallDependenceLowGrayLevelEmphasis  excluded
# ...

# %%
features_selection_pipeline('Z:/Lisa/CRC_AD/derivatives/hmri/MTsat_L.csv')
# Out:
# Non uniform features:  ['original_firstorder_10Percentile', 'original_firstorder_90Percentile', 'original_firstorder_Energy', 'original_firstorder_Entropy', 'original_firstorder_InterquartileRange', 'original_firstorder_Kurtosis', 'original_firstorder_Maximum', 'original_firstorder_MeanAbsoluteDeviation', 'original_firstorder_Mean', 'original_firstorder_Median', 'original_firstorder_Minimum', 'original_firstorder_Range', 'original_firstorder_RobustMeanAbsoluteDeviation', 'original_firstorder_RootMeanSquared', 'original_firstorder_Skewness', 'original_firstorder_TotalEnergy', 'original_firstorder_Uniformity', 'original_firstorder_Variance', 'original_glcm_Autocorrelation', 'original_glcm_ClusterProminence', 'original_glcm_ClusterShade', 'original_glcm_ClusterTendency', 'original_glcm_Contrast', 'original_glcm_Correlation', 'original_glcm_DifferenceAverage', 'original_glcm_DifferenceEntropy', 'original_glcm_DifferenceVariance', 'original_glcm_Id', 'original_glcm_Idm', 'original_glcm_Id
# ...

# %%
features_selection_pipeline('Z:/Lisa/CRC_AD/derivatives/hmri/MTsat_mean.csv')
# Out:
# Non uniform features:  ['original_firstorder_90Percentile', 'original_firstorder_Energy', 'original_firstorder_Entropy', 'original_firstorder_InterquartileRange', 'original_firstorder_Kurtosis', 'original_firstorder_Maximum', 'original_firstorder_MeanAbsoluteDeviation', 'original_firstorder_Mean', 'original_firstorder_Median', 'original_firstorder_Minimum', 'original_firstorder_Range', 'original_firstorder_RobustMeanAbsoluteDeviation', 'original_firstorder_RootMeanSquared', 'original_firstorder_Skewness', 'original_firstorder_TotalEnergy', 'original_firstorder_Uniformity', 'original_firstorder_Variance', 'original_glcm_Autocorrelation', 'original_glcm_ClusterProminence', 'original_glcm_ClusterShade', 'original_glcm_ClusterTendency', 'original_glcm_Contrast', 'original_glcm_Correlation', 'original_glcm_DifferenceAverage', 'original_glcm_DifferenceEntropy', 'original_glcm_DifferenceVariance', 'original_glcm_Id', 'original_glcm_Idm', 'original_glcm_Idmn', 'original_glcm_Idn', 'original_
# ...

# %%
df = pd.read_csv('Z:/Lisa/CRC_AD/derivatives/hmri/MTsat_mean.csv')
y = df['outcome']
X_0 = np.array(df['original_shape_MeshVolume']).reshape(-1,1)
X_1 = df[['original_shape_MeshVolume', 'original_firstorder_90Percentile']]
X_2 = df[['original_shape_MeshVolume', 'original_firstorder_90Percentile', 'original_firstorder_Kurtosis']]
X_3 = df[['original_shape_MeshVolume', 'original_firstorder_90Percentile', 'original_firstorder_Kurtosis', 
          'original_glcm_Imc1']]
X_4 = df[['original_shape_MeshVolume', 'original_firstorder_90Percentile', 'original_firstorder_Kurtosis', 
          'original_glcm_Imc1', 'original_ngtdm_Strength']]

y_pred_0 = get_ypred(X_0, y)
y_pred_1 = get_ypred(X_1, y)
y_pred_2 = get_ypred(X_2, y)
y_pred_3 = get_ypred(X_3, y)
y_pred_4 = get_ypred(X_4, y)

print(efron_rsquare(y, y_pred_0))
print(efron_rsquare(y, y_pred_1))
print(efron_rsquare(y, y_pred_2))
print(efron_rsquare(y, y_pred_3))
print(efron_rsquare(y, y_pred_4))
# Out:
# [[-0.00364205]]
# [[-0.00364654 -0.29857498]]
# [[-0.00348485 -0.28489393 -0.90944825]]
# [[-0.00347271 -0.31219718 -0.90414478 -0.1692669 ]]
# [[-0.00343743 -0.28048986 -0.91093586 -0.01069015  0.09387658]]
# 0.45849264383679955
# 0.46197865415146366
# 0.5076592264034725
# 0.507704882680577
# 0.5073763911484039

# %%
features_selection_pipeline('Z:/Lisa/CRC_AD/derivatives/hmri/PD_R.csv')
# Out:
# original_gldm_SmallDependenceLowGrayLevelEmphasis  excluded
# ...

# %%
features_selection_pipeline('Z:/Lisa/CRC_AD/derivatives/hmri/PD_L.csv')
# Out:
# original_gldm_SmallDependenceLowGrayLevelEmphasis  excluded
# ...

# %%
features_selection_pipeline('Z:/Lisa/CRC_AD/derivatives/hmri/PD_mean.csv')
# Out:
# original_gldm_SmallDependenceLowGrayLevelEmphasis  excluded
# ...

# %%
df = pd.read_csv('Z:/Lisa/CRC_AD/derivatives/hmri/PD_mean.csv')
y = df['outcome']
X_0 = np.array(df['original_shape_MeshVolume']).reshape(-1,1)
X_1 = df[['original_shape_MeshVolume', 'original_glcm_Imc1']]
X_2 = df[['original_shape_MeshVolume', 'original_glcm_Imc1', 'original_glrlm_GrayLevelNonUniformity']]

y_pred_0 = get_ypred(X_0, y)
y_pred_1 = get_ypred(X_1, y)
y_pred_2 = get_ypred(X_2, y)

print(efron_rsquare(y, y_pred_0))
print(efron_rsquare(y, y_pred_1))
print(efron_rsquare(y, y_pred_2))
# Out:
# [[-0.00364205]]
# [[-0.0036416  -0.02979418]]
# [[-0.00361957 -0.02976877 -0.00018107]]
# 0.45849264383679955
# 0.4585342746219936
# 0.4591462123289304

# %%
features_selection_pipeline('Z:/Lisa/CRC_AD/derivatives/hmri/R1_R.csv')
# Out:
# Non uniform features:  ['original_firstorder_10Percentile', 'original_firstorder_90Percentile', 'original_firstorder_Energy', 'original_firstorder_Entropy', 'original_firstorder_InterquartileRange', 'original_firstorder_Kurtosis', 'original_firstorder_Maximum', 'original_firstorder_MeanAbsoluteDeviation', 'original_firstorder_Mean', 'original_firstorder_Median', 'original_firstorder_Minimum', 'original_firstorder_Range', 'original_firstorder_RobustMeanAbsoluteDeviation', 'original_firstorder_RootMeanSquared', 'original_firstorder_Skewness', 'original_firstorder_TotalEnergy', 'original_firstorder_Uniformity', 'original_firstorder_Variance', 'original_glcm_Autocorrelation', 'original_glcm_ClusterProminence', 'original_glcm_ClusterShade', 'original_glcm_ClusterTendency', 'original_glcm_Contrast', 'original_glcm_Correlation', 'original_glcm_DifferenceAverage', 'original_glcm_DifferenceEntropy', 'original_glcm_DifferenceVariance', 'original_glcm_Id', 'original_glcm_Idm', 'original_glcm_Id
# ...

# %%
features_selection_pipeline('Z:/Lisa/CRC_AD/derivatives/hmri/R1_L.csv')
# Out:
# Non uniform features:  ['original_firstorder_10Percentile', 'original_firstorder_90Percentile', 'original_firstorder_Energy', 'original_firstorder_Entropy', 'original_firstorder_InterquartileRange', 'original_firstorder_Kurtosis', 'original_firstorder_Maximum', 'original_firstorder_MeanAbsoluteDeviation', 'original_firstorder_Mean', 'original_firstorder_Median', 'original_firstorder_Minimum', 'original_firstorder_Range', 'original_firstorder_RobustMeanAbsoluteDeviation', 'original_firstorder_RootMeanSquared', 'original_firstorder_Skewness', 'original_firstorder_TotalEnergy', 'original_firstorder_Uniformity', 'original_firstorder_Variance', 'original_glcm_Autocorrelation', 'original_glcm_ClusterProminence', 'original_glcm_ClusterShade', 'original_glcm_ClusterTendency', 'original_glcm_Contrast', 'original_glcm_Correlation', 'original_glcm_DifferenceAverage', 'original_glcm_DifferenceEntropy', 'original_glcm_DifferenceVariance', 'original_glcm_Id', 'original_glcm_Idm', 'original_glcm_Id
# ...

# %%
features_selection_pipeline('Z:/Lisa/CRC_AD/derivatives/hmri/R1_mean.csv')
# Out:
# Non uniform features:  ['original_firstorder_90Percentile', 'original_firstorder_Energy', 'original_firstorder_Entropy', 'original_firstorder_InterquartileRange', 'original_firstorder_Kurtosis', 'original_firstorder_Maximum', 'original_firstorder_MeanAbsoluteDeviation', 'original_firstorder_Mean', 'original_firstorder_Median', 'original_firstorder_Minimum', 'original_firstorder_Range', 'original_firstorder_RobustMeanAbsoluteDeviation', 'original_firstorder_RootMeanSquared', 'original_firstorder_Skewness', 'original_firstorder_TotalEnergy', 'original_firstorder_Uniformity', 'original_firstorder_Variance', 'original_glcm_Autocorrelation', 'original_glcm_ClusterProminence', 'original_glcm_ClusterShade', 'original_glcm_ClusterTendency', 'original_glcm_Contrast', 'original_glcm_Correlation', 'original_glcm_DifferenceAverage', 'original_glcm_DifferenceEntropy', 'original_glcm_DifferenceVariance', 'original_glcm_Id', 'original_glcm_Idm', 'original_glcm_Idmn', 'original_glcm_Idn', 'original_
# ...

# %%
df = pd.read_csv('Z:/Lisa/CRC_AD/derivatives/hmri/R1_mean.csv')
y = df['outcome']
X_0 = np.array(df['original_shape_MeshVolume']).reshape(-1,1)
X_1 = df[['original_shape_MeshVolume', 'original_firstorder_Skewness']]
X_2 = df[['original_shape_MeshVolume', 'original_firstorder_Skewness', 'original_firstorder_TotalEnergy']]
X_3 = df[['original_shape_MeshVolume', 'original_firstorder_Skewness', 'original_firstorder_TotalEnergy', 
          'original_firstorder_Variance']]
X_4 = df[['original_shape_MeshVolume', 'original_firstorder_Skewness', 'original_firstorder_TotalEnergy', 
          'original_firstorder_Variance', 'original_glcm_Imc1']]
X_5 = df[['original_shape_MeshVolume', 'original_firstorder_Skewness', 'original_firstorder_TotalEnergy', 
          'original_firstorder_Variance', 'original_glcm_Imc1', 'original_ngtdm_Busyness']]
X_6 = df[['original_shape_MeshVolume', 'original_firstorder_Skewness', 'original_firstorder_TotalEnergy', 
          'original_firstorder_Variance', 'original_glcm_Imc1', 'original_ngtdm_Busyness', 'original_ngtdm_Strength']]

y_pred_0 = get_ypred(X_0, y)
y_pred_1 = get_ypred(X_1, y)
y_pred_2 = get_ypred(X_2, y)
y_pred_3 = get_ypred(X_3, y)
y_pred_4 = get_ypred(X_4, y)
y_pred_5 = get_ypred(X_5, y)
y_pred_6 = get_ypred(X_6, y)

print(efron_rsquare(y, y_pred_0))
print(efron_rsquare(y, y_pred_1))
print(efron_rsquare(y, y_pred_2))
print(efron_rsquare(y, y_pred_3))
print(efron_rsquare(y, y_pred_4))
print(efron_rsquare(y, y_pred_5))
print(efron_rsquare(y, y_pred_6))
# Out:
# [[-0.00364205]]
# [[-0.0037511  -0.87842336]]
# [[-0.00467015 -0.96340506  0.00265988]]
# [[-0.00466402 -0.96096364  0.00265882  0.13435999]]
# [[-0.00466979 -0.96336556  0.00265957  0.01222121 -0.01219615]]
# [[-0.00467211 -0.96383072  0.00266353  0.01313649 -0.01684607  0.01324162]]
# [[-0.00486312 -0.97636368  0.00289636  0.01497877 -0.02188835 -0.00200286
#   -0.21740185]]
# 0.45849264383679955
# 0.47888022356022897
# 0.5065477966408658
# 0.5065120776673976
# 0.5065528530455816
# 0.5066167836389592
# 0.5113978463264155

# %%
features_selection_pipeline('Z:/Lisa/CRC_AD/derivatives/hmri/R2s_OLS_R.csv')
# Out:
# Non uniform features:  ['original_firstorder_10Percentile', 'original_firstorder_90Percentile', 'original_firstorder_Energy', 'original_firstorder_Entropy', 'original_firstorder_InterquartileRange', 'original_firstorder_Kurtosis', 'original_firstorder_Maximum', 'original_firstorder_MeanAbsoluteDeviation', 'original_firstorder_Mean', 'original_firstorder_Median', 'original_firstorder_Minimum', 'original_firstorder_Range', 'original_firstorder_RobustMeanAbsoluteDeviation', 'original_firstorder_RootMeanSquared', 'original_firstorder_Skewness', 'original_firstorder_TotalEnergy', 'original_firstorder_Uniformity', 'original_firstorder_Variance', 'original_glcm_Autocorrelation', 'original_glcm_ClusterProminence', 'original_glcm_ClusterShade', 'original_glcm_ClusterTendency', 'original_glcm_Contrast', 'original_glcm_Correlation', 'original_glcm_DifferenceAverage', 'original_glcm_DifferenceEntropy', 'original_glcm_DifferenceVariance', 'original_glcm_Id', 'original_glcm_Idm', 'original_glcm_Id
# ...

# %%
features_selection_pipeline('Z:/Lisa/CRC_AD/derivatives/hmri/R2s_OLS_L.csv')
# Out:
# Non uniform features:  ['original_firstorder_10Percentile', 'original_firstorder_90Percentile', 'original_firstorder_Energy', 'original_firstorder_Entropy', 'original_firstorder_InterquartileRange', 'original_firstorder_Kurtosis', 'original_firstorder_Maximum', 'original_firstorder_MeanAbsoluteDeviation', 'original_firstorder_Mean', 'original_firstorder_Median', 'original_firstorder_Minimum', 'original_firstorder_Range', 'original_firstorder_RobustMeanAbsoluteDeviation', 'original_firstorder_RootMeanSquared', 'original_firstorder_Skewness', 'original_firstorder_TotalEnergy', 'original_firstorder_Uniformity', 'original_firstorder_Variance', 'original_glcm_Autocorrelation', 'original_glcm_ClusterProminence', 'original_glcm_ClusterShade', 'original_glcm_ClusterTendency', 'original_glcm_Contrast', 'original_glcm_Correlation', 'original_glcm_DifferenceAverage', 'original_glcm_DifferenceEntropy', 'original_glcm_DifferenceVariance', 'original_glcm_Id', 'original_glcm_Idm', 'original_glcm_Id
# ...

# %%
features_selection_pipeline('Z:/Lisa/CRC_AD/derivatives/hmri/R2s_OLS_mean.csv')
# Out:
# Non uniform features:  ['original_firstorder_90Percentile', 'original_firstorder_Energy', 'original_firstorder_Entropy', 'original_firstorder_InterquartileRange', 'original_firstorder_Kurtosis', 'original_firstorder_Maximum', 'original_firstorder_MeanAbsoluteDeviation', 'original_firstorder_Mean', 'original_firstorder_Median', 'original_firstorder_Minimum', 'original_firstorder_Range', 'original_firstorder_RobustMeanAbsoluteDeviation', 'original_firstorder_RootMeanSquared', 'original_firstorder_Skewness', 'original_firstorder_TotalEnergy', 'original_firstorder_Uniformity', 'original_firstorder_Variance', 'original_glcm_Autocorrelation', 'original_glcm_ClusterProminence', 'original_glcm_ClusterShade', 'original_glcm_ClusterTendency', 'original_glcm_Contrast', 'original_glcm_Correlation', 'original_glcm_DifferenceAverage', 'original_glcm_DifferenceEntropy', 'original_glcm_DifferenceVariance', 'original_glcm_Id', 'original_glcm_Idm', 'original_glcm_Idmn', 'original_glcm_Idn', 'original_
# ...

# %%
df = pd.read_csv('Z:/Lisa/CRC_AD/derivatives/hmri/R2s_OLS_mean.csv')
y = df['outcome']
X_0 = np.array(df['original_shape_MeshVolume']).reshape(-1,1)
X_1 = df[['original_shape_MeshVolume', 'original_firstorder_TotalEnergy']]
X_2 = df[['original_shape_MeshVolume', 'original_firstorder_TotalEnergy', 'original_glcm_Imc2']]
X_3 = df[['original_shape_MeshVolume', 'original_firstorder_TotalEnergy', 'original_glcm_Imc2', 
          'original_glrlm_RunLengthNonUniformity']]
X_4 = df[['original_shape_MeshVolume', 'original_firstorder_TotalEnergy', 'original_glcm_Imc2', 
          'original_glrlm_RunLengthNonUniformity', 'original_glszm_GrayLevelVariance']]
X_5 = df[['original_shape_MeshVolume', 'original_firstorder_TotalEnergy', 'original_glcm_Imc2', 
          'original_glrlm_RunLengthNonUniformity', 'original_glszm_GrayLevelVariance', 
          'original_glszm_LargeAreaHighGrayLevelEmphasis']]
X_6 = df[['original_shape_MeshVolume', 'original_firstorder_TotalEnergy', 'original_glcm_Imc2', 
          'original_glrlm_RunLengthNonUniformity', 'original_glszm_GrayLevelVariance', 
          'original_glszm_LargeAreaHighGrayLevelEmphasis', 'original_ngtdm_Busyness']]

y_pred_0 = get_ypred(X_0, y)
y_pred_1 = get_ypred(X_1, y)
y_pred_2 = get_ypred(X_2, y)
y_pred_3 = get_ypred(X_3, y)
y_pred_4 = get_ypred(X_4, y)
y_pred_5 = get_ypred(X_5, y)
y_pred_6 = get_ypred(X_6, y)

print(efron_rsquare(y, y_pred_0))
print(efron_rsquare(y, y_pred_1))
print(efron_rsquare(y, y_pred_2))
print(efron_rsquare(y, y_pred_3))
print(efron_rsquare(y, y_pred_4))
print(efron_rsquare(y, y_pred_5))
print(efron_rsquare(y, y_pred_6))
# Out:
# [[-0.00364205]]
# [[-5.99758482e-11 -2.44957920e-08]]
# [[-5.99758482e-11 -2.44957920e-08  6.45424592e-13]]
# [[-1.98801662e-03 -4.50329144e-08  5.90470647e-06  2.92550662e-03]]
# [[-1.53316213e-03 -6.55080071e-07  4.61313192e-03 -9.93034751e-04
#    2.56568182e-01]]
# [[-4.54048947e-03  5.22753430e-07  5.40819199e-03  2.08952299e-03
#    2.85869382e-01  1.66404536e-06]]
# [[-4.54088794e-03  5.22986996e-07  5.40804629e-03  2.08993732e-03
#    2.85861711e-01  1.66417798e-06  6.19808108e-04]]
# 0.45849264383679955
# -0.013552024392031514
# -0.01355202439195824
# 0.11084552189308827
# 0.3901118644593188
# 0.42182282743593735
# 0.42182048412214823

# %%
features_n_R_MT = [93, 89, 26, 9]
features_n_R_PD = [93, 88, 17, 1]
features_n_R_R1 = [93, 89, 23, 7]
features_n_R_R2 = [93, 91, 18, 6]

features_n_L_MT = [93, 88, 23, 4]
features_n_L_PD = [93, 88, 18, 2]
features_n_L_R1 = [93, 89, 23, 7]
features_n_L_R2 = [93, 91, 20, 1]

features_n_m_MT = [93, 85, 22, 4]
features_n_m_PD = [93, 87, 21, 2]
features_n_m_R1 = [93, 88, 23, 6]
features_n_m_R2 = [93, 90, 21, 6]

# %%
plt.figure(figsize=(10, 2.5))

plt.plot([0,1,2,3], features_n_R_MT, label='MT')
plt.plot([0,1,2,3], features_n_R_PD, label='PD')
plt.plot([0,1,2,3], features_n_R_R1, label='R1')
plt.plot([0,1,2,3], features_n_R_R2, label='R2*')
#plt.xticks([0, 1, 2, 3], 
#           ['Extracted', 'Not correlated with volume', 'Not inter-correlated', 'Distinctive'], 
#           rotation=15
#          )
plt.xticks([], [])
plt.legend()
plt.ylabel('Number of features')
plt.title('Right hippocampi')
plt.show()

# %%
plt.figure(figsize=(10, 2.5))

plt.plot([0,1,2,3], features_n_L_MT, label='MT')
plt.plot([0,1,2,3], features_n_L_PD, label='PD')
plt.plot([0,1,2,3], features_n_L_R1, label='R1')
plt.plot([0,1,2,3], features_n_L_R2, label='R2*')
#plt.xticks([0, 1, 2, 3], 
#           ['Extracted', 'Not correlated with volume', 'Not inter-correlated', 'Distinctive'], 
#           rotation=15
#          )
plt.xticks([], [])
plt.legend()
plt.ylabel('Number of features')
plt.title('Left hippocampi')
plt.show()

# %%
plt.figure(figsize=(10, 2.5))

plt.plot([0,1,2,3], features_n_m_MT, label='MT')
plt.plot([0,1,2,3], features_n_m_PD, label='PD')
plt.plot([0,1,2,3], features_n_m_R1, label='R1')
plt.plot([0,1,2,3], features_n_m_R2, label='R2*')
plt.xticks([0, 1, 2, 3], 
           ['Extracted', 'Not correlated with volume', 'Not inter-correlated', 'Distinctive'], 
           #rotation=5
          )
plt.legend()
plt.ylabel('Number of features')
plt.title('Average between left and right hippocampi')
plt.show()
